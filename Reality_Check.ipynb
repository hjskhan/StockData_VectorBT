# %%
import vectorbt as vbt
import pandas as pd
import numpy as np
import datetime
import yfinance

# %%
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=2)

# %%
btc_price = vbt.YFData.download(
    'BTC-USD',
    interval='1m',
    missing_index=True,
    start=start_date.timestamp(),
    end=end_date.timestamp()
    ).get('Close')

# %%
btc_price,range_indexes = btc_price.vbt.range_split(n=100,range_len=1440)

# %%
def optimize_rsi(close,window,entry,exit):
    rsi = vbt.IndicatorFactory.from_talib('RSI').run(close, timeperiod=window).real
    return rsi<entry, rsi>exit

# %%
rsi_ind = vbt.IndicatorFactory(
            class_name='OptimizeRSI',
            short_name='rsi',
            input_names=['close'],
            param_names=['window', 'entry', 'exit'],
            output_names=['entries','exits']
        ).from_apply_func(
                optimize_rsi,
                window=14,
                entry=30,
                exit=70)

# %%
step_size=10
entries = np.arange(10,45,step=step_size,dtype=int)
exits = np.arange(55,95,step=step_size,dtype=int)
windows = np.arange(10,45,step=step_size,dtype=int)

# %%
rsi_res = rsi_ind.run(
        btc_price,
        window=windows,
        entry=entries,
        exit=exits,
        param_product=True)

# %%
rsi_entries = rsi_res.entries
rsi_exits = rsi_res.exits

# %%
rsi_entries.iloc[-1,:] = True

# %%
rsi_pf = vbt.Portfolio.from_signals(
        btc_price,
        rsi_entries,
        rsi_exits,
        freq='1T',
        fees=0.001)

# %%
fig = rsi_pf.total_return().vbt.volume(
        x_level='rsi_exit',
        y_level='rsi_entry',
        z_level='rsi_window',
        slider_level='split_idx')

# %%
fig.show()
# Out:
# <div>                            <div id="98bf3da8-8748-4c84-a477-7d46357751dd" class="plotly-graph-div" style="height:590.0px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98bf3da8-8748-4c84-a477-7d46357751dd")) {                    Plotly.newPlot(                        "98bf3da8-8748-4c84-a477-7d46357751dd",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>rsi_window: %{z}<br>value: %{value}<extra></extra>","name":"0","opacity":0.2,"surface":{"count":15},"visible":true,"x":[55,55,55,55,55,55,55,55,55,55,55,55,55,55,55,55,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,75,75,75,75,75,75,75,75,75,75,75,75,75,75,75,75,85,85,85,85,85,85,85,85,85,85,85,85,85,85,85,85],"y":[10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40],"z":[10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40],"type":"volume","uid":"491d706d-6ae3-447f-b265-dc6df853bec7","value":[-0.005398432979536807,-0.0009990009990008275,-0.0009990009990008275,-0.0009990009990008275,-0.02773264493898367,-0.0069506496199376495,-0.0006774255750652003,-0.0009990009990008275,-0.049053521637189734,-0.023958116095896854,-0.012533907380187798,-0.00474020160370145,-0.07488703950966326,-0.04408091489451579,-0.028240498651211112,-0.019130411901030583,-0.01074066026517741,-0.0009990009990008275,-0.0009990009990008275,-0.0009990009990008275,-0.031676949293678834,-0.00474020160370145,-0.0014639405672350848,-0.0009990009990008275,-0.04683469218034503,-0.017983395474049358,-0.012066678951392476,-0.005769931396824148,-0.06002422896268229,-0.028384045170037384,-0.02139183032405697,-0.016671777216879492,-0.008703057171750857,-0.0009990009990008275,-0.0009990009990008275,-0.0009990009990008275,-0.02924839185188702,-0.004903125040553249,0.002560158978331657,-0.0009990009990008275,-0.03639905557810692,-0.015185886702122816,-0.005525605541595695,-0.0035804252595528397,-0.041213222327115634,-0.021370488323183282,-0.013607567008123028,-0.0061930900382728285,-0.008972290686575093,-0.0009990009990008275,-0.0009990009990008275,-0.0009990009990008275,-0.021696396996810564,-0.0035804252595528397,0.0018233088514848816,-0.0009990009990008275,-0.024549145123424695,-0.005558356173285404,0.0018500990202255708,-0.0035804252595528397,-0.023658525885795142,-0.011662256549048636,-0.007480582529552038,-0.005785390985228531]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>rsi_window: %{z}<br>value: %{value}<extra></extra>","name":"1","opacity":0.2,"surface":{"count":15},"visible":false,"x":[55,55,55,55,55,55,55,55,55,55,55,55,55,55,55,55,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,75,75,75,75,75,75,75,75,75,75,75,75,75,75,75,75,85,85,85,85,85,85,85,85,85,85,85,85,85,85,85,85],"y":[10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40],"z":[10,20,30,40,10,20,30,40,10,20,30,40,10,20,30,40,1 ...

# %% [markdown]
# ##### HeatMap

# %%
rsi_res = rsi_ind.run(
        btc_price,
        window=14, ### changed window=windows to window=14 for 2d graph
        entry=entries,
        exit=exits,
        param_product=True)
rsi_entries = rsi_res.entries
rsi_exits = rsi_res.exits
rsi_entries.iloc[-1,:] = True

rsi_pf = vbt.Portfolio.from_signals(
        btc_price,
        rsi_entries,
        rsi_exits,
        freq='1T',
        fees=0.001)

#### Plotting HeatMap
fig = rsi_pf.total_return().vbt.heatmap(
    x_level='rsi_exit',
    y_level='rsi_entry',
    slider_level='split_idx'
    )
fig.show()
# Out:
# <div>                            <div id="0d36567d-c27e-4477-87dd-066e51dea30e" class="plotly-graph-div" style="height:555px; width:605px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d36567d-c27e-4477-87dd-066e51dea30e")) {                    Plotly.newPlot(                        "0d36567d-c27e-4477-87dd-066e51dea30e",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>value: %{z}<extra></extra>","name":"0","visible":true,"x":[55,65,75,85],"y":[10,20,30,40],"type":"heatmap","uid":"59259ae1-201a-47e5-998c-b97e7bb45dab","z":[[0.0013529158368513095,-0.0008606877574963789,-0.0001109530096113076,0.0018233088514848816],[-0.021757053358599024,-0.02348879474766747,-0.018537233429067327,-0.011804244417641599],[-0.03550782776299144,-0.03334939491256904,-0.024339231190332242,-0.01231213828758726],[-0.0546114183466338,-0.03943995792276709,-0.026866995382824683,-0.01250347705676532]]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>value: %{z}<extra></extra>","name":"1","visible":false,"x":[55,65,75,85],"y":[10,20,30,40],"type":"heatmap","uid":"4328b52c-585f-46c6-bd24-7ec94ff0cb9a","z":[[0.0013529158368513095,-0.0008606877574963789,-0.0001109530096113076,0.0019046292820253542],[-0.019815780920638276,-0.02202660320003986,-0.017338501845795804,-0.01059728934708886],[-0.03314115639080569,-0.031448489114622336,-0.022690006109290835,-0.010642583001723126],[-0.05564127416399103,-0.038332904264479876,-0.026216287836934242,-0.01184316501722762]]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>value: %{z}<extra></extra>","name":"2","visible":false,"x":[55,65,75,85],"y":[10,20,30,40],"type":"heatmap","uid":"ad46d302-093d-4f27-9be7-84838b9deb20","z":[[0.0003525632735778572,-0.0008606877574963789,-0.0001109530096113076,0.0014813788522050687],[-0.020794985934703476,-0.02202660320003986,-0.01775362309517021,-0.01101525839355304],[-0.034107049341464094,-0.031448489114622336,-0.023102866638020317,-0.01106053291407207],[-0.05604722840394359,-0.03958835377373717,-0.026222925329848865,-0.011849900480050763]]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>value: %{z}<extra></extra>","name":"3","visible":false,"x":[55,65,75,85],"y":[10,20,30,40],"type":"heatmap","uid":"65dc85e3-965b-436e-af64-a03fd4da551c","z":[[0.0013529158368513095,-0.0008606877574963789,-0.0001109530096113076,0.0019878706676178127],[-0.019815780920638276,-0.02202660320003986,-0.01889578723513182,-0.01051508666018961],[-0.03314115639080569,-0.031448489114622336,-0.024238810633734717,-0.01056038407796322],[-0.0550643721670 ...

# %% [markdown]
# ###### the parammeters is not giving any common value on slider

# %%
rsi_res = rsi_ind.run(
        btc_price,
        window=14, ### changed window=windows to window=14 for 2d graph
        entry=entries,
        exit=exits,
        param_product=True)
rsi_entries = rsi_res.entries
rsi_exits = rsi_res.exits
rsi_entries.iloc[-1,:] = True

rsi_pf = vbt.Portfolio.from_signals(
        btc_price,
        rsi_entries,
        rsi_exits,
        freq='1T',
        fees=0.001)

# taking average all the windows
rsi_tot_returns = rsi_pf.total_return().groupby(level=['rsi_exit','rsi_entry']).mean()

print(rsi_tot_returns)
# Plotting HeatMap
fig = rsi_tot_returns.vbt.heatmap(
    x_level='rsi_exit',
    y_level='rsi_entry',
#     slider_level='split_idx'
    )
fig.show()
# Out:
# rsi_exit  rsi_entry
# 55        10          -0.003854
#           20          -0.016009
#           30          -0.027660
#           40          -0.053446
# 65        10          -0.002482
#           20          -0.014598
#           30          -0.021842
#           40          -0.036931
# 75        10          -0.000223
#           20          -0.009574
#           30          -0.012533
#           40          -0.020642
# 85        10           0.002518
#           20          -0.005832
#           30          -0.001740
#           40          -0.004219
# Name: total_return, dtype: float64
# <div>                            <div id="51a03f94-7c15-4919-ae70-b8911fc52378" class="plotly-graph-div" style="height:455px; width:605px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51a03f94-7c15-4919-ae70-b8911fc52378")) {                    Plotly.newPlot(                        "51a03f94-7c15-4919-ae70-b8911fc52378",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"rsi_exit: %{x}<br>rsi_entry: %{y}<br>value: %{z}<extra></extra>","x":[55,65,75,85],"y":[10,20,30,40],"type":"heatmap","uid":"d077b430-c758-45fc-8e5a-7b4c5cdc5af3","z":[[-0.0038535223223434157,-0.0024817844385471985,-0.00022348024350960004,0.0025178750165541987],[-0.016008876347990756,-0.014598065074497726,-0.009574164756150258,-0.005831505382247105],[-0.027659674061220278,-0.02184195199271827,-0.012533097946483256,-0.0017403033568889256],[-0.05344619791542494,-0.03693136835211318,-0.020642088278832273,-0.004219328976725636]]}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"co ...

# %% [markdown]
#  ###### All are negative returns or very very small. Therefore, not good to go with

# %% [markdown]
# #### BoxPlot

# %%
rsi_res = rsi_ind.run(
        btc_price,
        window=14, 
        entry=20, # from previous heatmap
        exit=80,
        param_product=True)
rsi_entries = rsi_res.entries
rsi_exits = rsi_res.exits
rsi_entries.iloc[-1,:] = True

rsi_pf = vbt.Portfolio.from_signals(
        btc_price,
        rsi_entries,
        rsi_exits,
        freq='1T',
        fees=0.001)

# taking average all the windows
rsi_tot_returns = rsi_pf.total_return()

print(rsi_tot_returns)
# Plotting BoxPlot
box = vbt.plotting.Box(
            data=rsi_tot_returns,
            trace_names=['RSI_strat']
            )
box.fig.show()
# Out:
# rsi_window  rsi_entry  rsi_exit  split_idx
# 14          20         80        0           -0.016124
#                                  1           -0.014922
#                                  2           -0.015339
#                                  3           -0.014841
#                                  4           -0.015623
#                                                 ...
#                                  95          -0.004752
#                                  96          -0.005104
#                                  97          -0.005679
#                                  98          -0.005332
#                                  99          -0.004665
# Name: total_return, Length: 100, dtype: float64
# <div>                            <div id="bbbf3b78-a8f0-4b1c-9fe3-88b833a315af" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbbf3b78-a8f0-4b1c-9fe3-88b833a315af")) {                    Plotly.newPlot(                        "bbbf3b78-a8f0-4b1c-9fe3-88b833a315af",                        [{"name":"RSI_strat","showlegend":true,"type":"box","uid":"ef9fe344-dbc1-4f9d-b214-cc626ed43dbf","y":[-0.01612408631953528,-0.014922407384867569,-0.015338549303264983,-0.014840564042368953,-0.01562269260004271,-0.016346266189627555,-0.014110692245823201,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.015437811832553763,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.01520349487183239,-0.013444944466806988,-0.01359444107744821,-0.01351129746766702,-0.011475957930004057,-0.011273869677834369,-0.016927679839139387,-0.019539035711754735,-0.029316211439619762,-0.02405356900359891,-0.02410706499875161,-0.019023146133981327,-0.019023146133981327,-0.019023146133981327,-0.019023146133981327,-0.019023146133981327,-0.017804400573954524,-0.010492973648949544,-0.005126727333688592,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.00735584310593552,-0.005240007607597193,-0.005240007607597193,-0.00671447408615677,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005240007607597193,-0.005514068881212779,-0.004560789941684505,-0.004560789941684505,-0.004560789941684505,-0.006197854849404081,-0.004560789941684505,-0.004574428782407409,-0.0077703334352635526,-0.006357662257579619,-0.006465089987603534,-0.005605807032648045,-0.008398094701854575,-0.00725152763629211,-0.007174238002474027,-0.006162459058421774,-0.006351481864578972,-0.008046228956520877,-0.00807782534770439,-0.007336247630234709,-0.007734362159146997,-0.0074986739137033,-0.007435203360864335,-0.00817851714378378,-0.007412912280490929,-0.006648696269557917,-0.0071491964247660175,-0.007637668670534765,-0.0061667704772546015,-0.005255374443408698,-0.004751591629979401,-0.005104072645672062,-0.005678532528756648,-0.005331616636658936,-0.00466512352212348]}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...
