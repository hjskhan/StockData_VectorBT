# %%
import vectorbt as vbt
import yfinance
import pandas as pd
import numpy as np
import datetime

# %%
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days = 2)

# %%
btc_price = vbt.YFData.download(
    ['BTC-USD','ETH-USD'],
    interval = '1m',
    start = start_date,
    end = end_date,
    missing_index = True
).get('Close')

# %%
def custom_indicator(close, ma_window=14,rsi_window=25,entry = 30, exit = 70):
    close_5m = close.resample('5T').last()
    rsi = vbt.RSI.run(close,window = rsi_window).rsi
    rsi, _ = rsi.align(
        close,
        broadcast_axis = 0,
        method = 'ffill',
        join = 'right'
        )
    close = close.to_numpy()
    rsi = rsi.to_numpy()
    ma = vbt.MA.run(close, ma_window).ma.to_numpy()
    trend = np.where(rsi > entry, -1, 0)
    trend = np.where((rsi < exit) & (close < ma), 1, trend)
    return trend

# %%
ind = vbt.IndicatorFactory(
    class_name='Combination',
    short_name='comb',
    input_names=['close'],
    output_names=['value'],
    param_names=['ma_window','rsi_window','entry','exit']
    ).from_apply_func(
            custom_indicator,
            rsi_window = 14,
            ma_window = 50, 
            entry = 30,
            exit = 70,
            keep_pd = True
            )

# %%
res = ind.run(
    btc_price,
    rsi_window=[14,21,50],
    ma_window = [21,50,100],
    entry = [30,40],
    exit = [70,80],
    param_product = True
)

# %%
entries = res.value == 1.0
exits = res.value == -1.0

# %%
pf = vbt.Portfolio.from_signals(btc_price,entries,exits)

# %%
print(pf.total_return().to_string())
# Out:
# comb_ma_window  comb_rsi_window  comb_entry  comb_exit  symbol
# 21              14               30          70         BTC-USD   -0.024799
#                                                         ETH-USD   -0.048212
#                                              80         BTC-USD   -0.024799
#                                                         ETH-USD   -0.049734
#                                  40          70         BTC-USD   -0.024667
#                                                         ETH-USD   -0.045870
#                                              80         BTC-USD   -0.024667
#                                                         ETH-USD   -0.047396
#                 21               30          70         BTC-USD   -0.024944
#                                                         ETH-USD   -0.049564
#                                              80         BTC-USD   -0.024727
#                                                         ETH-USD   -0.049564
#                                  40          70         BTC-USD   -0.028433
#                                                         ETH-USD   -0.050884
#                                              80         BTC-USD   -0.028216
#                                                         ETH-USD   -0.050884
#                 50               30          70         BTC-USD   -0.023699
#                                                         ETH-USD   -0.050168
#                                              80         BTC-USD   -0.024912
#                                                         ETH-USD   -0.050168
#                                  40          70         BTC-USD   -0.022039
#                                                         ETH-USD   -0.046028
#                                              80         BTC-USD   -0.023253
#                                                         ETH-USD   -0.046028
# 50              14               30          70         BTC-USD   -0.019343
#                                                         ETH-USD   -0.043994
#                                              80         BTC-USD   -0.022602
#                                                         ETH-USD   -0.044465
#                                  40          70         BTC-USD   -0.019577
#                                                         ETH-USD   -0.043456
#                                              80         BTC-USD   -0.022835
#                                                         ETH-USD   -0.043927
#                 21               30          70         BTC-USD   -0.024045
#                                                         ETH-USD   -0.045353
#                                              80         BTC-USD   -0.023481
#                                                         ETH-USD   -0.045342
#                                  40          70         BTC-USD   -0.024521
#                                                         ETH-USD   -0.044616
#                                              80         BTC-USD   -0.023957
#                                                         ETH-USD   -0.044604
#                 50               30          70         BTC-USD   -0.023481
#                                                         ETH-USD   -0.045342
#                                              80         BTC-USD   -0.023481
#                                                         ETH-USD   -0.045342
#                                  40          70         BTC-USD   -0.021711
#                                                         ETH-USD   -0.042678
#                                              80         BTC-USD   -0.021711
#                                                         ETH-USD   -0.042678
# 100             14               30          70         BTC-USD   -0.007528
#                                                         ETH-USD   -0.034807
#                                              80         BTC-USD   -0.012312
#                                                         ETH-USD   -0.034425
#                                  40          70         BTC-USD   -0.006102
#                                                         ETH-USD   -0.033112
#                                              80         BTC-USD   -0.010892
#                                                         ETH-USD   -0.032729
#                 21               30          70         BTC-USD   -0.014634
#                                                         ETH-USD   -0.036067
#                                              80         BTC-USD   -0.014512
#                                                         ETH-USD   -0.034551
#                                  40          70         BTC-USD   -0.014213
#                                                         ETH-USD   -0.037502
#                                              80         BTC-USD   -0.014091
#                                                         ETH-USD   -0.035988
#                 50               30          70         BTC-USD   -0.014512
#                                                         ETH-USD   -0.036573
#                                              80         BTC-USD   -0.014512
#                                                         ETH-USD   -0.035703
#                                  40          70         BTC-USD   -0.014512
#                                                         ETH-USD   -0.036456
#                                              80         BTC-USD   -0.014512
#                                                         ETH-USD   -0.035587

# %%
# max value of returns
print(pf.total_return().max())
# params for max returns
print(pf.total_return().idxmax())
# Out:
# -0.006101909261361413
# (100, 14, 40, 70, 'BTC-USD')

# %%
returns = pf.total_return()

# %%
## to get a particular input returns (here --- ETH-USD)
returns = returns[returns.index.isin(['ETH-USD'],level = 'symbol')]
# max value of returns
print(returns.max())
# params for max returns
print(returns.idxmax())
# Out:
# -0.032729031815398456
# (100, 14, 40, 80, 'ETH-USD')

# %% [markdown]
# ###### ----------------

# %% [markdown]
# ###### ----------------

# %%
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days = 2)

# %%
btc_price = vbt.YFData.download(
    ['BTC-USD','ETH-USD'],
    interval = '1m',
    start = start_date,
    end = end_date,
    missing_index = True
).get('Close')

# %%
def custom_indicator(close, ma_window=14,rsi_window=25,entry = 30, exit = 70):
    close_5m = close.resample('5T').last()
    rsi = vbt.RSI.run(close,window = rsi_window).rsi
    rsi, _ = rsi.align(
        close,
        broadcast_axis = 0,
        method = 'ffill',
        join = 'right'
        )
    close = close.to_numpy()
    rsi = rsi.to_numpy()
    ma = vbt.MA.run(close, ma_window).ma.to_numpy()
    trend = np.where(rsi > entry, -1, 0)
    trend = np.where((rsi < exit) & (close < ma), 1, trend)
    return trend

# %%
ind = vbt.IndicatorFactory(
    class_name='Combination',
    short_name='comb',
    input_names=['close'],
    output_names=['value'],
    param_names=['ma_window','rsi_window','entry','exit']
    ).from_apply_func(
            custom_indicator,
            rsi_window = 14,
            ma_window = 50, 
            entry = 30,
            exit = 70,
            keep_pd = True
            )

# %%
res = ind.run(
    btc_price,
    rsi_window = np.arange(10, 40, step=3, dtype=int) ,
    ma_window = np.arange(20, 200, step=15, dtype=int) ,
    entry = np.arange(10, 40, step=4, dtype=int) ,
    exit = np.arange(60, 85, step=4, dtype=int) ,
    param_product = True
)

# %%
entries = res.value == 1.0
exits = res.value == -1.0

# %%
pf = vbt.Portfolio.from_signals(btc_price,entries,exits)

# %%
returns = pf.total_return()

# %%
print(returns.to_string())
# Out:
# comb_ma_window  comb_rsi_window  comb_entry  comb_exit  symbol
# 20              10               10          60         BTC-USD   -0.029740
#                                                         ETH-USD   -0.049654
#                                              64         BTC-USD   -0.029920
#                                                         ETH-USD   -0.052476
#                                              68         BTC-USD   -0.028940
#                                                         ETH-USD   -0.050636
#                                              72         BTC-USD   -0.027925
#                                                         ETH-USD   -0.050906
#                                              76         BTC-USD   -0.027147
#                                                         ETH-USD   -0.051114
#                                              80         BTC-USD   -0.028460
#                                                         ETH-USD   -0.052481
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052533
#                                  14          60         BTC-USD   -0.029740
#                                                         ETH-USD   -0.049600
#                                              64         BTC-USD   -0.029920
#                                                         ETH-USD   -0.052422
#                                              68         BTC-USD   -0.028940
#                                                         ETH-USD   -0.050583
#                                              72         BTC-USD   -0.027925
#                                                         ETH-USD   -0.050852
#                                              76         BTC-USD   -0.027147
#                                                         ETH-USD   -0.051060
#                                              80         BTC-USD   -0.028460
#                                                         ETH-USD   -0.052428
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052480
#                                  18          60         BTC-USD   -0.029740
#                                                         ETH-USD   -0.049600
#                                              64         BTC-USD   -0.029920
#                                                         ETH-USD   -0.052422
#                                              68         BTC-USD   -0.028940
#                                                         ETH-USD   -0.050583
#                                              72         BTC-USD   -0.027925
#                                                         ETH-USD   -0.050852
#                                              76         BTC-USD   -0.027147
#                                                         ETH-USD   -0.051060
#                                              80         BTC-USD   -0.028460
#                                                         ETH-USD   -0.052428
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052480
#                                  22          60         BTC-USD   -0.029740
#                                                         ETH-USD   -0.049600
#                                              64         BTC-USD   -0.029920
#                                                         ETH-USD   -0.052422
#                                              68         BTC-USD   -0.028940
#                                                         ETH-USD   -0.050583
#                                              72         BTC-USD   -0.027925
#                                                         ETH-USD   -0.050852
#                                              76         BTC-USD   -0.027147
#                                                         ETH-USD   -0.051060
#                                              80         BTC-USD   -0.028460
#                                                         ETH-USD   -0.052428
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052480
#                                  26          60         BTC-USD   -0.029737
#                                                         ETH-USD   -0.049419
#                                              64         BTC-USD   -0.029918
#                                                         ETH-USD   -0.052241
#                                              68         BTC-USD   -0.028937
#                                                         ETH-USD   -0.050401
#                                              72         BTC-USD   -0.027923
#                                                         ETH-USD   -0.050671
#                                              76         BTC-USD   -0.027145
#                                                         ETH-USD   -0.050879
#                                              80         BTC-USD   -0.028457
#                                                         ETH-USD   -0.052247
#                                              84         BTC-USD   -0.028505
#                                                         ETH-USD   -0.052299
#                                  30          60         BTC-USD   -0.029737
#                                                         ETH-USD   -0.047986
#                                              64         BTC-USD   -0.029918
#                                                         ETH-USD   -0.050813
#                                              68         BTC-USD   -0.028937
#                                                         ETH-USD   -0.048970
#                                              72         BTC-USD   -0.027923
#                                                         ETH-USD   -0.049240
#                                              76         BTC-USD   -0.027145
#                                                         ETH-USD   -0.049448
#                                              80         BTC-USD   -0.028457
#                                                         ETH-USD   -0.050819
#                                              84         BTC-USD   -0.028505
#                                                         ETH-USD   -0.050871
#                                  34          60         BTC-USD   -0.029850
#                                                         ETH-USD   -0.047405
#                                              64         BTC-USD   -0.030031
#                                                         ETH-USD   -0.050233
#                                              68         BTC-USD   -0.029050
#                                                         ETH-USD   -0.048389
#                                              72         BTC-USD   -0.028036
#                                                         ETH-USD   -0.048660
#                                              76         BTC-USD   -0.027258
#                                                         ETH-USD   -0.048868
#                                              80         BTC-USD   -0.028571
#                                                         ETH-USD   -0.050239
#                                              84         BTC-USD   -0.028618
#                                                         ETH-USD   -0.050291
#                                  38          60         BTC-USD   -0.027857
#                                                         ETH-USD   -0.047871
#                                              64         BTC-USD   -0.028038
#                                                         ETH-USD   -0.050698
#                                              68         BTC-USD   -0.027056
#                                                         ETH-USD   -0.048855
#                                              72         BTC-USD   -0.026039
#                                                         ETH-USD   -0.049125
#                                              76         BTC-USD   -0.025260
#                                                         ETH-USD   -0.049333
#                                              80         BTC-USD   -0.026575
#                                                         ETH-USD   -0.050703
#                                              84         BTC-USD   -0.026623
#                                                         ETH-USD   -0.050755
#                 13               10          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  14          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  18          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  22          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  26          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  30          60         BTC-USD   -0.026921
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028516
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  34          60         BTC-USD   -0.027048
#                                                         ETH-USD   -0.051725
#                                              64         BTC-USD   -0.028643
#                                                         ETH-USD   -0.052645
#                                              68         BTC-USD   -0.028635
#                                                         ETH-USD   -0.052850
#                                              72         BTC-USD   -0.028635
#                                                         ETH-USD   -0.052348
#                                              76         BTC-USD   -0.028635
#                                                         ETH-USD   -0.052488
#                                              80         BTC-USD   -0.028635
#                                                         ETH-USD   -0.052488
#                                              84         BTC-USD   -0.028635
#                                                         ETH-USD   -0.052529
#                                  38          60         BTC-USD   -0.026992
#                                                         ETH-USD   -0.050043
#                                              64         BTC-USD   -0.028587
#                                                         ETH-USD   -0.050966
#                                              68         BTC-USD   -0.028579
#                                                         ETH-USD   -0.051171
#                                              72         BTC-USD   -0.028579
#                                                         ETH-USD   -0.050668
#                                              76         BTC-USD   -0.028579
#                                                         ETH-USD   -0.050808
#                                              80         BTC-USD   -0.028579
#                                                         ETH-USD   -0.050808
#                                              84         BTC-USD   -0.028579
#                                                         ETH-USD   -0.050849
#                 16               10          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  14          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  18          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  22          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  26          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  30          60         BTC-USD   -0.029835
#                                                         ETH-USD   -0.050987
#                                              64         BTC-USD   -0.029642
#                                                         ETH-USD   -0.050132
#                                              68         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051106
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.051056
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  34          60         BTC-USD   -0.029751
#                                                         ETH-USD   -0.050240
#                                              64         BTC-USD   -0.029557
#                                                         ETH-USD   -0.049385
#                                              68         BTC-USD   -0.028423
#                                                         ETH-USD   -0.050359
#                                              72         BTC-USD   -0.028423
#                                                         ETH-USD   -0.050310
#                                              76         BTC-USD   -0.028423
#                                                         ETH-USD   -0.051783
#                                              80         BTC-USD   -0.028423
#                                                         ETH-USD   -0.051783
#                                              84         BTC-USD   -0.028423
#                                                         ETH-USD   -0.051783
#                                  38          60         BTC-USD   -0.029686
#                                                         ETH-USD   -0.049942
#                                              64         BTC-USD   -0.029493
#                                                         ETH-USD   -0.049086
#                                              68         BTC-USD   -0.028358
#                                                         ETH-USD   -0.050061
#                                              72         BTC-USD   -0.028358
#                                                         ETH-USD   -0.050012
#                                              76         BTC-USD   -0.028358
#                                                         ETH-USD   -0.051485
#                                              80         BTC-USD   -0.028358
#                                                         ETH-USD   -0.051485
#                                              84         BTC-USD   -0.028358
#                                                         ETH-USD   -0.051485
#                 19               10          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  14          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  18          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  22          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  26          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  30          60         BTC-USD   -0.025320
#                                                         ETH-USD   -0.046765
#                                              64         BTC-USD   -0.027264
#                                                         ETH-USD   -0.050193
#                                              68         BTC-USD   -0.028632
#                                                         ETH-USD   -0.051890
#                                              72         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              76         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              80         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                              84         BTC-USD   -0.028507
#                                                         ETH-USD   -0.052529
#                                  34          60         BTC-USD   -0.025424
#                                                         ETH-USD   -0.047495
#                                              64         BTC-USD   -0.027369
#                                                         ETH-USD   -0.050921
#                                              68         BTC-USD   -0.028736
#                                                         ETH-USD   -0.052616
#                                              72         BTC-USD   -0.028612
#                                                         ETH-USD   -0.053254
#                                              76         BTC-USD   -0.028612
#                                                         ETH-USD   -0.053254
#                                              80         BTC-USD   -0.028612
#                                                         ETH-USD   -0.053254
#                                              84         BTC-USD   -0.028612
#                                                         ETH-USD   -0.053254
#                                  38          60         BTC-USD   -0.025654
#                                                         ETH-USD   -0.047423
#                                              64         BTC-USD   -0.027597
#                                                         ETH-USD   -0.050849
#                                              68         BTC-USD   -0.028965
#                                                         ETH-USD   -0.052544
#                                              72         BTC-USD   -0.028840
#                                                         ETH-USD   -0.053183
#                                              76         BTC-USD   -0.028840
#                                                         ETH-USD   -0.053183
#                                              80         BTC-USD   -0.028840
#                                                         ETH-USD   -0.053183
#                                              84         BTC-USD   -0.028840
#                                                         ETH-USD   -0.053183
#                 22               10          60         BTC-USD   -0.024781
#                                                         ETH-USD   -0.046235
#                                              64         BTC-USD   -0.027098
#                                                         ETH-USD   -0.051075
#                                              68         BTC-USD   -0.028786
#                                                         ETH-USD   -0.052505
#                                              72         BTC-USD   -0.028390
#                                                         ETH-USD   -0.052082
#                                              76         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              80         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              84         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                  14          60         BTC-USD   -0.024781
#                                                         ETH-USD   -0.046235
#                                              64         BTC-USD   -0.027098
#                                                         ETH-USD   -0.051075
#                                              68         BTC-USD   -0.028786
#                                                         ETH-USD   -0.052505
#                                              72         BTC-USD   -0.028390
#                                                         ETH-USD   -0.052082
#                                              76         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              80         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              84         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                  18          60         BTC-USD   -0.024781
#                                                         ETH-USD   -0.046235
#                                              64         BTC-USD   -0.027098
#                                                         ETH-USD   -0.051075
#                                              68         BTC-USD   -0.028786
#                                                         ETH-USD   -0.052505
#                                              72         BTC-USD   -0.028390
#                                                         ETH-USD   -0.052082
#                                              76         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              80         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              84         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                  22          60         BTC-USD   -0.024781
#                                                         ETH-USD   -0.046235
#                                              64         BTC-USD   -0.027098
#                                                         ETH-USD   -0.051075
#                                              68         BTC-USD   -0.028786
#                                                         ETH-USD   -0.052505
#                                              72         BTC-USD   -0.028390
#                                                         ETH-USD   -0.052082
#                                              76         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              80         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              84         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                  26          60         BTC-USD   -0.024781
#                                                         ETH-USD   -0.046235
#                                              64         BTC-USD   -0.027098
#                                                         ETH-USD   -0.051075
#                                              68         BTC-USD   -0.028786
#                                                         ETH-USD   -0.052505
#                                              72         BTC-USD   -0.028390
#                                                         ETH-USD   -0.052082
#                                              76         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              80         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                              84         BTC-USD   -0.028049
#                                                         ETH-USD   -0.052082
#                                  30          60         BTC-USD   -0.025119
#                                                         ETH-USD   -0.046396
#                                              64         BTC-USD   -0.027435
#                                                         ETH-USD   -0.051235
#                                              68         BTC-USD   -0.029123
#                                                         ETH-USD   -0.052664
#                                              72         BTC-USD   -0.028727
#                                                         ETH-USD   -0.052241
#                                              76         BTC-USD   -0.028386
#                                                         ETH-USD   -0.052241
#                                              80         BTC-USD   -0.028386
#                                                         ETH-USD   -0.052241
#                                              84         BTC-USD   -0.028386
#                                                         ETH-USD   -0.052241
#                                  34          60         BTC-USD   -0.025102
#                                                         ETH-USD   -0.049213
#                                              64         BTC-USD   -0.027418
#                                                         ETH-USD   -0.054037
#                                              68         BTC-USD   -0.029106
#                                                         ETH-USD   -0.055463
#                                              72         BTC-USD   -0.028710
#                                                         ETH-USD   -0.055041
#                                              76         BTC-USD   -0.028369
#                                                         ETH-USD   -0.055041
#                                              80         BTC-USD   -0.028369
#                                                         ETH-USD   -0.055041
#                                              84         BTC-USD   -0.028369
#                                                         ETH-USD   -0.055041
#                                  38          60         BTC-USD   -0.025213
#                                                         ETH-USD   -0.050608
#                                              64         BTC-USD   -0.027528
#                                                         ETH-USD   -0.055426
#                                              68         BTC-USD   -0.029216
#                                                         ETH-USD   -0.056849
#                                              72         BTC-USD   -0.028820
#                                                         ETH-USD   -0.056428
#                                              76         BTC-USD   -0.028479
#                                                         ETH-USD   -0.056428
#                                              80         BTC-USD   -0.028479
#                                                         ETH-USD   -0.056428
#                                              84         BTC-USD   -0.028479
#                                                         ETH-USD   -0.056428
#                 25               10          60         BTC-USD   -0.023317
#                                                         ETH-USD   -0.046691
#                                              64         BTC-USD   -0.026708
#                                                         ETH-USD   -0.052578
#                                              68         BTC-USD   -0.028648
#                                                         ETH-USD   -0.053480
#                                              72         BTC-USD   -0.028217
#                                                         ETH-USD   -0.053135
#                                              76         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              80         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              84         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                  14          60         BTC-USD   -0.023317
#                                                         ETH-USD   -0.046691
#                                              64         BTC-USD   -0.026708
#                                                         ETH-USD   -0.052578
#                                              68         BTC-USD   -0.028648
#                                                         ETH-USD   -0.053480
#                                              72         BTC-USD   -0.028217
#                                                         ETH-USD   -0.053135
#                                              76         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              80         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              84         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                  18          60         BTC-USD   -0.023317
#                                                         ETH-USD   -0.046691
#                                              64         BTC-USD   -0.026708
#                                                         ETH-USD   -0.052578
#                                              68         BTC-USD   -0.028648
#                                                         ETH-USD   -0.053480
#                                              72         BTC-USD   -0.028217
#                                                         ETH-USD   -0.053135
#                                              76         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              80         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              84         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                  22          60         BTC-USD   -0.023317
#                                                         ETH-USD   -0.046691
#                                              64         BTC-USD   -0.026708
#                                                         ETH-USD   -0.052578
#                                              68         BTC-USD   -0.028648
#                                                         ETH-USD   -0.053480
#                                              72         BTC-USD   -0.028217
#                                                         ETH-USD   -0.053135
#                                              76         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              80         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              84         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                  26          60         BTC-USD   -0.023317
#                                                         ETH-USD   -0.046691
#                                              64         BTC-USD   -0.026708
#                                                         ETH-USD   -0.052578
#                                              68         BTC-USD   -0.028648
#                                                         ETH-USD   -0.053480
#                                              72         BTC-USD   -0.028217
#                                                         ETH-USD   -0.053135
#                                              76         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              80         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
#                                              84         BTC-USD   -0.028000
#                                                         ETH-USD   -0.052111
# ...
#                                  14          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041660
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044235
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040823
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039829
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  18          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041660
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044235
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040823
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039829
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  22          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041660
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044235
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040823
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039829
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  26          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041660
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044235
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040823
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039829
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  30          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041660
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044235
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040823
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039829
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  34          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.041809
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044384
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.040972
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.039979
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.041702
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.041702
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041702
#                                  38          60         BTC-USD   -0.020926
#                                                         ETH-USD   -0.042246
#                                              64         BTC-USD   -0.013469
#                                                         ETH-USD   -0.044820
#                                              68         BTC-USD   -0.013603
#                                                         ETH-USD   -0.041409
#                                              72         BTC-USD   -0.012765
#                                                         ETH-USD   -0.040416
#                                              76         BTC-USD   -0.013662
#                                                         ETH-USD   -0.042139
#                                              80         BTC-USD   -0.013620
#                                                         ETH-USD   -0.042139
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.042139
#                 37               10          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  14          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  18          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  22          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  26          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  30          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044450
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042626
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041194
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039789
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041553
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041553
#                                  34          60         BTC-USD   -0.016171
#                                                         ETH-USD   -0.044621
#                                              64         BTC-USD   -0.016433
#                                                         ETH-USD   -0.042797
#                                              68         BTC-USD   -0.014311
#                                                         ETH-USD   -0.041365
#                                              72         BTC-USD   -0.013756
#                                                         ETH-USD   -0.039961
#                                              76         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041724
#                                              80         BTC-USD   -0.013450
#                                                         ETH-USD   -0.041724
#                                              84         BTC-USD   -0.013323
#                                                         ETH-USD   -0.041724
#                                  38          60         BTC-USD   -0.016025
#                                                         ETH-USD   -0.045006
#                                              64         BTC-USD   -0.016287
#                                                         ETH-USD   -0.043183
#                                              68         BTC-USD   -0.014165
#                                                         ETH-USD   -0.041751
#                                              72         BTC-USD   -0.013610
#                                                         ETH-USD   -0.040348
#                                              76         BTC-USD   -0.013304
#                                                         ETH-USD   -0.042110
#                                              80         BTC-USD   -0.013304
#                                                         ETH-USD   -0.042110
#                                              84         BTC-USD   -0.013177
#                                                         ETH-USD   -0.042110

# %%
# max value of returns
print(returns.max())
# params for max returns
print(returns.idxmax())
# Out:
# -0.004398480560554248
# (125, 16, 30, 64, 'BTC-USD')

# %%
## to get a particular input returns (here --- ETH-USD)
returns = returns[returns.index.isin(['ETH-USD'],level = 'symbol')]
# max value of returns
print(returns.max())
# params for max returns
print(returns.idxmax())
# Out:
# -0.027056213168829685
# (155, 16, 10, 68, 'ETH-USD')

# %%
fig = returns.vbt.heatmap(
        x_level = 'comb_ma_window',
        y_level = 'comb_rsi_window'
        )
fig.show()
# Out:
# <div>                            <div id="5541e1de-a552-4cb7-b55b-2126fd5b8794" class="plotly-graph-div" style="height:433px; width:628px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5541e1de-a552-4cb7-b55b-2126fd5b8794")) {                    Plotly.newPlot(                        "5541e1de-a552-4cb7-b55b-2126fd5b8794",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_ma_window: %{x}<br>comb_rsi_window: %{y}<br>value: %{z}<extra></extra>","x":[20,35,50,65,80,95,110,125,140,155,170,185],"y":[10,13,16,19,22,25,28,31,34,37],"type":"heatmap","uid":"b7bae692-2cdd-4eeb-acb1-cb0130ee8a85","z":[[-0.05075538294811295,-0.0488970734343458,-0.04437456033955911,-0.037866720918493545,-0.034662745693161835,-0.0383121044779486,-0.039761041395601354,-0.03642100466417787,-0.03716161687117463,-0.03469285946707714,-0.03450301952022428,-0.04216342936339814],[-0.05084865659315128,-0.049414812076276605,-0.045738390238920915,-0.03839715183702722,-0.036328062576939005,-0.04128294235060693,-0.038674401921461196,-0.036281585617193884,-0.03596049122698375,-0.03364557446424257,-0.033087755365739754,-0.04026951256083493],[-0.05148532238622096,-0.04782466818079825,-0.04514667759410912,-0.03790611202565842,-0.036113462768377645,-0.042012445653275846,-0.03945063565283959,-0.03617966514526913,-0.03586810307697533,-0.033300952414908665,-0.03202553503792615,-0.03973107469977308],[-0.05318254288957746,-0.048600998264165585,-0.04558351829571919,-0.03895368277144257,-0.03455787589822876,-0.041108563927626136,-0.03771624209172628,-0.036278241582513714,-0.03488311431164732,-0.03322178343559557,-0.03304161302944905,-0.03972749515811671],[-0.05642760906325961,-0.04778031597055971,-0.04514052311875389,-0.03865902094570387,-0.035712283326096925,-0.04192619820205536,-0.03795319079356304,-0.03660751658712428,-0.034528887213079285,-0.03360342200197465,-0.03309944902974991,-0.041568781982767006],[-0.05645525455644886,-0.04778031597055971,-0.04514052311875389,-0.037961402134171464,-0.03321453515565423,-0.040610467999118785,-0.03674996436417089,-0.03614080432039771,-0.03507759739856511,-0.0332974061301897,-0.033512916906597356,-0.041651977283379014],[-0.05522935916682499,-0.04778031597055971,-0.045342080926863704,-0.038338305113583576,-0.03452500189868246,-0.04068614743961419,-0.037100504333249094,-0.03625989997381083,-0.0361194307873393,-0.03333428697868527,-0.0337162391485856,-0.04150690733204911],[-0.05387025086556449,-0.048002380904381,-0.045342080926863704,-0.038338305113583576,-0.03484522792089351,-0.04068614743961419,-0.037264073939023916,-0.03611093889685236,-0.035680606739440464,-0.03349849635911056,-0.033554897645052935,-0.040928682906009754],[-0.05159064687230412,-0.04581772029425921,-0.045342080926863704,-0.038195169562417135,-0.0339733010686281,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03602488880558994,-0.033239471816809925,-0.03381523820453708,-0.04213924089770444],[-0.05215061692778591,-0.04646051530821097,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03542216700755205,-0.033239471816809925,-0.03381523820453708,-0.04211019823994889]]}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","line ...

# %%
fig = returns.vbt.heatmap(
        x_level = 'comb_ma_window',
        y_level = 'comb_entry'
        )
fig.show()
# Out:
# <div>                            <div id="7118332a-1c51-4f11-a905-843be219d5dd" class="plotly-graph-div" style="height:406px; width:654px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7118332a-1c51-4f11-a905-843be219d5dd")) {                    Plotly.newPlot(                        "7118332a-1c51-4f11-a905-843be219d5dd",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_ma_window: %{x}<br>comb_entry: %{y}<br>value: %{z}<extra></extra>","x":[20,35,50,65,80,95,110,125,140,155,170,185],"y":[10,14,18,22,26,30,34,38],"type":"heatmap","uid":"a7c167ee-2c85-41bd-b2f3-ab8f8792f81d","z":[[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.03381523820453708,-0.04155296194067233],[-0.055261472929758214,-0.048002380904381,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03537528744634912,-0.033239471816809925,-0.03381523820453708,-0.04172422568819087],[-0.05215061692778591,-0.04646051530821097,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03542216700755205,-0.033239471816809925,-0.03381523820453708,-0.04211019823994889]]}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222 ...

# %%
returns = pf.total_return()

# %%
fig = returns.vbt.heatmap(
        x_level = 'comb_ma_window',
        y_level = 'comb_entry',
        slider_level = 'symbol',
        )
fig.show()
# Out:
# <div>                            <div id="8a72e119-bb04-4e0a-91c6-9dfb2b1ac85c" class="plotly-graph-div" style="height:506px; width:654px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a72e119-bb04-4e0a-91c6-9dfb2b1ac85c")) {                    Plotly.newPlot(                        "8a72e119-bb04-4e0a-91c6-9dfb2b1ac85c",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_ma_window: %{x}<br>comb_entry: %{y}<br>value: %{z}<extra></extra>","name":"BTC-USD","visible":true,"x":[20,35,50,65,80,95,110,125,140,155,170,185],"y":[10,14,18,22,26,30,34,38],"type":"heatmap","uid":"90d00166-1b16-4e55-a5b4-b48a737cb77f","z":[[-0.028312452293729536,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009233206543454742,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.028312452293729536,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009233206543454742,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.028312452293729536,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009233206543454742,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.028312452293729536,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009233206543454742,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.028312452293729536,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009233206543454742,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.02811944600485532,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.009036410544169513,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.029362534544570308,-0.018772691476705745,-0.02348089748022389,-0.0168483520609432,-0.014874397711552093,-0.015286835051773551,-0.01228024627803336,-0.00943533243438722,-0.01001780437716107,-0.010483334360744579,-0.01132363216308363,-0.01332266512769266],[-0.03159620635178612,-0.019516891716253894,-0.02348089748022389,-0.0168483520609432,-0.014936872343156722,-0.015385902979405302,-0.012360430459229547,-0.009515747568833603,-0.01008058700388716,-0.011570287566762972,-0.01132363216308363,-0.013176869700235586]]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_ma_window: %{x}<br>comb_entry: %{y}<br>value: %{z}<extra></extra>","name":"ETH-USD","visible":false,"x":[20,35,50,65,80,95,110,125,140,155,170,185],"y":[10,14,18,22,26,30,34,38],"type":"heatmap","uid":"394fe999-e4c2-44fd-989e-870ca7e0baa2","z":[[-0.052689537717836715,-0.04778031597055971,-0.045342080926863704,-0.038195169562417135,-0.03470157245349071,-0.040634921523067365,-0.03700605857984982,-0.035852614494934584,-0.03573302020282924,-0.033239471816809925,-0.0338152382 ...

# %%
returns = pf.total_return()
returns = returns.groupby(level=['comb_exit','comb_entry','symbol']).mean()

# %%
fig = returns.vbt.heatmap(
        x_level = 'comb_exit',
        y_level = 'comb_entry',
        slider_level = 'symbol',
        )
fig.show()
# Out:
# <div>                            <div id="d11bf31c-92cf-45b5-83b3-122c7c6cef6d" class="plotly-graph-div" style="height:572px; width:589px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d11bf31c-92cf-45b5-83b3-122c7c6cef6d")) {                    Plotly.newPlot(                        "d11bf31c-92cf-45b5-83b3-122c7c6cef6d",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_exit: %{x}<br>comb_entry: %{y}<br>value: %{z}<extra></extra>","name":"BTC-USD","visible":true,"x":[60,64,68,72,76,80,84],"y":[10,14,18,22,26,30,34,38],"type":"heatmap","uid":"dabdfd82-f87f-4fe4-9e2a-7f35be01ce0b","z":[[-0.017468597239441715,-0.0159924010417944,-0.01571147708011707,-0.01551267711861276,-0.015339653034084922,-0.015328843121375875,-0.015379394514339218],[-0.01746852992558005,-0.015992332467208787,-0.015711407134813785,-0.015512605792255881,-0.015339582263509146,-0.015328771715770715,-0.01537932140514087],[-0.01746565476323938,-0.015989449335618276,-0.015708515258376063,-0.01550970316144625,-0.015336685201731554,-0.015325870917099254,-0.015376419266921381],[-0.01744988397095256,-0.015973647500665135,-0.015692672761048673,-0.015493810798839706,-0.015320799332339595,-0.015309969479444303,-0.015360508841985466],[-0.017468277002775714,-0.0159921258788115,-0.015711228117002558,-0.01551245954107426,-0.01533940967788568,-0.015328650191696679,-0.015379186944158957],[-0.017369460310892735,-0.01589313162595716,-0.015612207678708228,-0.015413426885669391,-0.015240352407109723,-0.015229606083399167,-0.015280185810622517],[-0.017305865964333488,-0.015829425450442722,-0.015548523531594098,-0.015349719637439802,-0.015176694078746946,-0.015165884289160133,-0.01521650043301675],[-0.017214030191968523,-0.01573718994616589,-0.015456170806090581,-0.015257399869590788,-0.01508433355441251,-0.0150735612665189,-0.015124185776112886]]},{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hoverongaps":false,"hovertemplate":"comb_exit: %{x}<br>comb_entry: %{y}<br>value: %{z}<extra></extra>","name":"ETH-USD","visible":false,"x":[60,64,68,72,76,80,84],"y":[10,14,18,22,26,30,34,38],"type":"heatmap","uid":"22528274-f41b-4924-b641-d1c122db97fd","z":[[-0.041035248098106256,-0.04055940489883237,-0.03912113665460097,-0.039084031117833685,-0.039221483311536805,-0.03962652397845696,-0.039599540108468285],[-0.04103439836513779,-0.04055855826562337,-0.03912028835393402,-0.039083180903204055,-0.03922063249424671,-0.039625674501156935,-0.039598689785492795],[-0.0410326520086165,-0.04055678490543437,-0.03911850613964799,-0.03908141122663835,-0.03921887995228009,-0.03962391576117006,-0.03959693282476547],[-0.04103626428268884,-0.04056034122955728,-0.03912207544075415,-0.03908503856597788,-0.03922254224980093,-0.03962757301604233,-0.03960059518385783],[-0.041027742479662885,-0.04055189500174506,-0.03911360980671193,-0.039076545463269295,-0.0392140059185421,-0.03961906611083164,-0.03959205380946381],[-0.04104650680195243,-0.04057051303760971,-0.03913227120807749,-0.03909540980043384,-0.03923286185910198,-0.039637857544776105,-0.039610909143548166],[-0.04125350190966961,-0.0407771193531793,-0.03933895326447061,-0.03930200425060162,-0.03943930443011249,-0.03984424311270494,-0.039817291709438825],[-0.041274409000981574,-0.040797809621600206,-0.03935998700282555,-0.039 ...

# %%
returns = pf.total_return()
fig = returns.vbt.volume(
        x_level = 'comb_ma_window',
        y_level = 'comb_entry',
        z_level = 'comb_exit',
        slider_level = 'symbol',
        )
fig.show()
# Out:
# <div>                            <div id="e6ab6cca-690e-4e3f-ad1a-c1eae45f5791" class="plotly-graph-div" style="height:590.0px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6ab6cca-690e-4e3f-ad1a-c1eae45f5791")) {                    Plotly.newPlot(                        "e6ab6cca-690e-4e3f-ad1a-c1eae45f5791",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"hovertemplate":"comb_ma_window: %{x}<br>comb_entry: %{y}<br>comb_exit: %{z}<br>value: %{value}<extra></extra>","name":"BTC-USD","opacity":0.2,"surface":{"count":15},"visible":true,"x":[20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,35,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,65,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,80,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,95,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,110,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,125,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,155,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185,185],"y":[10,10,10,10,10,10,10,14,14,14,14,14,14,14,18,18,18,18,18,18,18,22,22,22,22,22,22,22,26,26,26,26,26,26,26,30,30,30,30,30,30,30,34,34,34,34,34,34,34,38,38,38,38,38,38,38,10,10,10,10,10,10,10,14,14,14,14,14,14,14,18,18,18,18,18,18,18,22,22,22,22,22,22,22,26,26,26,26,26,26,26,30,30,30,30,30,30,30,34,34,34,34,34,34,34,38,38,38,38,38,38,38,10,10,10,10,10,10,10,14,14,14,14,14,14,14,18,18,18,18,18,18,18,22,22,22,22,22,22,22,26,26,26,26,26,26,26,30,30,30,30,30,30,30,34,34,34,34,34,34,34,38,38,38,38,38,38,38,10,10,10,10,10,10,10,14,14,14,14,14,14,14,18,18,18,18,18,18,18,22,22,22,22,22,22,22,26,26,26,26,26,26,26,30,30,30,30,30,30 ...
